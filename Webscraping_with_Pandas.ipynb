# %% [markdown]
# **Web Scraping with pandas.**
#
# Disclaimer: This only works if the website has tables.

# %%
pip install pandas

# %%
import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/List_of_countries_in_the_Eurovision_Song_Contest'

country = pd.read_html(url)
df = country[1]
df.head(30)
# Out:
#                      Country     Broadcaster(s)[12]  Debut year  \
# 0                    Albania                   RTSH        2004
# 1                  Andorra †                   RTVA        2004
# 2                    Armenia                  AMPTV        2006
# 3                  Australia                    SBS        2015
# 4                    Austria                    ORF        1957
# 5                 Azerbaijan                    İTV        2008
# 6                  Belarus ◇                   BTRC        2004
# 7                    Belgium          RTBF / VRT[a]        1956
# 8   Bosnia and Herzegovina †                   BHRT        1993
# 9                 Bulgaria †                    BNT        2005
# 10                   Croatia                    HRT        1993
# 11                    Cyprus                   CyBC        1981
# 12                Czechia[b]                     ČT        2007
# 13                   Denmark                     DR        1957
# ...

# %% [markdown]
# # New Section

# %%
url2 = 'https://waploaded.com/'

six = pd.read_html(url2)
df = six[6]
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-9b70c9614263> in <cell line: 3>()
#       1 url2 = 'https://waploaded.com/'
#       2
# ----> 3 six = pd.read_html(url2)
#       4 df = six[6]
#       5 df.head(10)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links)
#    1203     io = stringify_path(io)
#    1204
# -> 1205     return _parse(
# ...
